# %%
"""
Evan Turner
This is my testing program to convert NOAA NAM formatted files to the TXBLEND winds
for import into https://github.com/twdb/coastal-spill 

Eventually this code will get ingested to https://github.com/evanleeturner/nam-dataserver


This is for my own internal testing and devlopment purposes.

"""
import pandas as pd
import numpy as np
import os
import logging
import datetime
import functools
import tarfile
import tabulate
my_level = logging.DEBUG  #set to the level you want, eg. ERROR, WARNING, INFO, DEBUG
logger = logging.getLogger()
logging.basicConfig(level=my_level)
logger.setLevel(my_level)  #have to set the level twice - I don't know why this is, but it just is!

logger.error("Error level message")
logger.warning("Warning level message")
logger.info("Info level message")
logger.debug("Debug level message")
# Out:
# ERROR:root:Error level message
# WARNING:root:Warning level message
# INFO:root:Info level message
# DEBUG:root:Debug level message

# %%
#libraries copied from wind_calcs.py
#https://github.com/evanleeturner/nam-dataserver/blob/main/src/namdataserver/wind_calcs.py
import numpy as np

def wind_spddir_to_uv(wspd,wdir):
    """
    calculated the u and v wind components from wind speed and direction
    Input:
        wspd: wind speed
        wdir: wind direction
    Output:
        u: u wind component
        v: v wind component
    """

    rad = 4.0*np.arctan(1)/180.
    u = -wspd*np.sin(rad*wdir)
    v = -wspd*np.cos(rad*wdir)

    return u,v

def wind_uv_to_dir(U,V):
    """
    Calculates the wind direction from the u and v component of wind.
    Takes into account the wind direction coordinates is different than the
    trig unit circle coordinate. If the wind directin is 360 then returns zero
    (by %360)
    Inputs:
      U = west/east direction (wind from the west is positive, from the east is negative)
      V = south/noth direction (wind from the south is positive, from the north is negative)
    """
    WDIR= (270-np.rad2deg(np.arctan2(V,U)))%360
    return WDIR

def wind_uv_to_spd(U,V):
    """
    Calculates the wind speed from the u and v wind components
    Inputs:
      U = west/east direction (wind from the west is positive, from the east is negative)
      V = south/noth direction (wind from the south is positive, from the north is negative)
    """
    WSPD = np.sqrt(np.square(U)+np.square(V))
    return WSPD


# Below is used for calculing the angle between two wind vectors
def unit_vector(vector):
    """ Returns the unit vector of the vector.  """
    return vector / np.linalg.norm(vector)

def angle_between(v1, v2):
    """
    Calcualates the angle between two wind vecotrs. Utilizes the cos equation:
                cos(theta) = (u dot v)/(magnitude(u) dot magnitude(v))
    Input:
        v1 = vector 1. A numpy array, list, or tuple with
             u in the first index and v in the second --> vector1 = [u1,v1]
        v2 = vector 2. A numpy array, list, or tuple with
             u in the first index and v in the second --> vector2 = [u2,v2]
    Output:
    Returns the angle in radians between vectors 'v1' and 'v2'::
            >>> angle_between((1, 0, 0), (0, 1, 0))
            1.5707963267948966
            >>> angle_between((1, 0, 0), (1, 0, 0))
            0.0
            >>> angle_between((1, 0, 0), (-1, 0, 0))
            3.141592653589793
    """
    v1_u = unit_vector(v1)
    v2_u = unit_vector(v2)
    angle = np.arccos(np.dot(v1_u, v2_u))
    if np.isnan(angle):
        if (v1_u == v2_u).all():
            return np.rad2deg(0.0)
        else:
            return np.rad2deg(np.pi)
    return np.rad2deg(angle)

# %%
def Print_Winds_TXBLEND_FMT(bigframe, twdb_wind_list, outputfolder):
    """
    Function prints a large combined dataframe of wind data in the TXBLEND wndq format file.  
    This format was originally what was delivered to TWDB by the TAMU modeling group through a web interface
    
    The function converts a dataframe that looks like this:
    
    	station	Datetime	SPD_mph	DIR
    0	twdb000	2022-08-14 18:00:00	15.128582	102.088511
    1	twdb001	2022-08-14 18:00:00	14.335636	108.621309
    2	twdb002	2022-08-14 18:00:00	15.999258	85.801288
    
    
    Tp the ending file format with fixed with crazyness like this:

    :*******Wind Data (3Hourly) Time in GMT****
    **3-hourly winds from NAM  model for station  twdb135 28.248   -96.326
     50, number of days of this record
    2022 03 19 00   11.0  354.8
    2022 03 19 03    9.4   12.2
    2022 03 19 06   10.5   31.9
    2022 03 19 09   16.5   48.4
    2022 03 19 12   16.4   49.8
    2022 03 19 15   15.8   60.4
    2022 03 19 18   12.0   70.3
    
    To accomplish this, we use a library called tabulate (https://pypi.org/project/tabulate/), 
    various string formats, and pandas.
    
    """
    logging.debug("Entering Print_Winds_TXBLEND_FMT() with bigframe of len {}, {}, {}"
                  .format(len(bigframe),twdb_wind_list,outputfolder))
    logging.info("Writing wind data in TXBLEND format: STARTING")
    
    #error checking...
    isdir = os.path.isdir(outputfolder)
    if not isdir:
        logging.info("The specified output directory {} does not exist.  Trying to create it now...".format(outputfolder))
        try:
            os.mkdir(outputfolder)
            logging.info("Succesfully created {}".format(outputfolder))
        except OSError as err:
            logging.error("Could not create directory {}.  Quitting!  OS error: {0}".format(outputfolder,err))
    
    isfile = os.path.isfile(twdb_wind_list)
    if not isfile:
        logging.error("CRITICAL: Could not locate valid TWDB wind listing file specified at {}  Exiting."
                      .format(twdb_wind_list))
        return
        
        
    
    try: 
        listdf = pd.read_csv(twdb_wind_list)
        logging.debug("Openned twdb_wind_list for reading with {} entries".format(len(listdf)))
    except:
        logging.error("CRITICAL: Pandas had critical error trying to open our wind list file {}"
                      .format(twdb_wind_list))
        return
    
    #we expect to have a dataframe with these exact columns.  Otherwise lets quit out and respond why.
    expected_columns = ['station', 'Datetime', 'SPD_mph', 'DIR']  
    logging.debug("Running check on our df columns {} to expected {}".format(bigframe.columns,expected_columns))
        
    #some crazy lamba function testing to see if our columns are exactly the same.  I lifted this from:
    #https://www.digitalocean.com/community/tutorials/how-to-compare-two-lists-in-python
    if not functools.reduce(lambda x, y : x and y, map(lambda p, q: p == q,expected_columns,bigframe.columns), True): 
        logging.error("CRITICAL: Our dataframe columns are NOT what we expected.  What was passed in is {} \n We expected {}"
                      .format(bigframe.columns,expected_columns))
        return
    
    for i in bigframe['station'].unique():
        logging.debug("Processing station {}".format(i))
        tmp = bigframe.loc[(bigframe['station'] == i)].copy()
        logging.debug("Our sliced df has len {} and looks like {}".format(len(tmp),tmp.head(2)))
        tmp['STRTIME'] = tmp['Datetime'].dt.strftime('%Y %m %d %H')
        tmp['HOUR'] = tmp['Datetime'].dt.strftime('%H')
        
        #drop any duplicates - if they exist...
        tmp.drop_duplicates(subset=['Datetime'],inplace=True)
        
    
        #some crazy slicing here to get only the 3-hourly wind data...
        tmp  = tmp [(tmp['HOUR'] == '00') | (tmp['HOUR'] == '03')
                    | (tmp['HOUR'] == '06') | (tmp['HOUR'] == '09')
                   | (tmp['HOUR'] == '12') | (tmp['HOUR'] == '15')
                | (tmp['HOUR'] == '18') | (tmp['HOUR'] == '21')]
        #how many days are in the record??
        count = int(len(tmp)/8)
        
        tmp = tmp[['STRTIME', 'SPD_mph','DIR']]
        
        series = listdf.loc[listdf['station'] == i].squeeze()
        #need to separate the values from series to for python format print to work
        lon = series['lon']
        lat = series['lat']
        #for help with format printing, check out https://www.w3schools.com/python/ref_string_format.asp
        header_ln2 = "**3-hourly winds from NAM  model for station  {} {lat:.3f}   {lon:.3f}\n"
        header_ln3 = str(count)+ " number of days of this record\n"
        
        
        content = tabulate.tabulate(tmp.values.tolist(), tablefmt="plain", numalign="right",floatfmt=".1f",stralign="right")
        
        mypath = os.path.join(outputfolder,i)
        try:
            f = open(mypath+".wndq", "w")
        except:
            logging.error("CRITICAL: could not write file {} ".format(mypath+".wndq"))
            break              
        f.write("*******Wind Data (3Hourly) Time in GMT****\n")
        f.write(header_ln2.format(i,lat=lat,lon=lon))
        f.write(header_ln3)
        f.write(content)
        f.close()
        logging.debug("Writing file {} COMPLETED".format(mypath+".wndq"))
        
        
    logging.info("Print_Winds_TXBLEND_FMT() COMPLETE")
    return

# %%
def make_tarfile(output_filename, source_dir):
    """
    Method is a simple wrapper for tarfile library to create a tar.gz out of an entire directory.
    """
    logging.debug("Entering make_tarfile() with output {} and source {}".format(output_filename, source_dir))
    with tarfile.open(output_filename, "w:gz") as tar:
        tar.add(source_dir, arcname=os.path.basename(source_dir))
    logging.info("Wrote tarfile {}".format(output_filename))

def read_TWDB_NAM_csv(fn,folder,columns_name, convertUVwinds=True):
    """
    Function reads a single file from disk in TWDB NAM CSV format.  
    
    An example file "nam_218_20220814_1800_000.csv" would look like:
    
    UGRD_P0_L103_GLC0,VGRD_P0_L103_GLC0,station
    -6.6131005,1.416339,twdb000
    -6.0731006,2.046339,twdb001
    -7.1331005,-0.5236609,twdb002
    -7.4331,1.036339,twdb003
    -6.7131004,1.936339,twdb004
    -5.8631005,2.2063391,twdb005
    -5.3731003,2.376339,twdb006
    -5.8531003,-1.2136608,twdb007
    -7.8431005,0.2863391,twdb008
    -8.1331005,1.8463391,twdb009
    -7.1031003,2.616339,twdb010
    """
    try:
        tmp = pd.read_csv(os.path.join (folder, fn))
    except:
        logging.error("read_TWDB_NAM_csv() CRITICAL: Failed to read file {} in folder {} \n exiting the program early!".format(fn, folder))
        return -1
    logging.debug("read_TWDB_NAM_csv() Detected the timestamp from file {} as {} {} {} {} {}"
                  .format(fn,fn[8:12], fn[12:14], fn[14:16],fn[17:19], fn[23:25]))
    #datetime requires integers, create datetime column from the filename and apply deltatime from hour 
    tmp['Datetime'] = datetime.datetime( int(fn[8:12]),int( fn[12:14]), int(fn[14:16]),int(fn[17:19])) +  datetime.timedelta(hours=int(fn[23:25]))
    
    #our our columns winds in U and V components, if so process to mph and dir
    if convertUVwinds:
        #convert U and V to speedmph and dir - converting from mps to mph with constant 2.23694
        tmp['SPD_mph'] = wind_uv_to_spd(tmp[columns_name[0]],tmp[columns_name[1]])* 2.23694
        tmp['DIR'] = wind_uv_to_dir(tmp[columns_name[0]],tmp[columns_name[1]])
        tmp.drop([columns_name[0],columns_name[1]], axis=1, inplace=True)
        
        
    logging.debug("read_TWDB_NAM_csv() Our completed ingested file looks like: \n {}".format(tmp.head(2)))
    
    return tmp

# %%
def Convert_TWDB(import_folder,OUTPUT_folder,TMP_folder,windlist):
    """
    Function imports Wind data in csv format, using the filename to create a datetime index. 
    Filename follows the NOAA NAM formatting scheme where the datetime is embedded in the filename.  
    See the NOAA site: https://www.ncei.noaa.gov/products/weather-climate-models/north-american-mesoscale
    """
     #our U and V constants we are expecting from the files
    U = 'UGRD_P0_L103_GLC0'
    V= 'VGRD_P0_L103_GLC0'

    try:
        files = os.listdir(import_folder)  
    except:
        logging.error("We could not open the folder specified {}".format(import_folder))

        
    data = []
    logging.info("Loading wind data from disk: STARTING")
    for i in files: 
        tmp = read_TWDB_NAM_csv(i,import_folder,[U,V],convertUVwinds=True)
        if tmp is None:
            logging.error("Quitting abnormally, see errors from above")
            return
        else:
            data.append(tmp)
    logging.info("Loading wind data from disk: COMPLETED - with {} records".format(len(data)))


    #combine the list of dataframes data[] into one giant frame...
    df = pd.concat(data, axis=0)
    df.sort_values(by=['Datetime'],inplace=True)
    logging.debug("Created one dataframe with record length {} from {} to {}".format(len(df),df['Datetime'].min(),df['Datetime'].max()))
    logging.debug("Our dataframe looks like: \n {} \n {}".format(df.head(2),df.tail(2)))
    
    Print_Winds_TXBLEND_FMT(df,windlist,TMP_folder)
    #add tar.gz operation for output_folder
    
    outputfile = os.path.join(OUTPUT_folder,"twdbq.tar")
    make_tarfile(outputfile, TMP_folder)

# %%
Convert_TWDB('nam_218_20220814_1800',"","twdb-winds-test","NAMwinds.latlist.csv")
# Out:
# INFO:root:Loading wind data from disk: STARTING
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_000.csv as 2022 08 14 18 00
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime    SPD_mph         DIR
# 0  twdb000 2022-08-14 18:00:00  15.128582  102.088511
# 1  twdb001 2022-08-14 18:00:00  14.335636  108.621309
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_001.csv as 2022 08 14 18 01
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime    SPD_mph        DIR
# 0  twdb000 2022-08-14 19:00:00  16.388135  104.79092
# 1  twdb001 2022-08-14 19:00:00  16.224203  112.02847
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_002.csv as 2022 08 14 18 02
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime    SPD_mph         DIR
# 0  twdb000 2022-08-14 20:00:00  15.558004  116.570418
# 1  twdb001 2022-08-14 20:00:00  15.899475  122.710633
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_003.csv as 2022 08 14 18 03
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime    SPD_mph         DIR
# 0  twdb000 2022-08-14 21:00:00  13.957058  119.795092
# 1  twdb001 2022-08-14 21:00:00  13.627715  124.268829
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_004.csv as 2022 08 14 18 04
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime    SPD_mph         DIR
# 0  twdb000 2022-08-14 22:00:00  13.136723  116.013411
# 1  twdb001 2022-08-14 22:00:00  12.357022  119.923266
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_005.csv as 2022 08 14 18 05
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime    SPD_mph         DIR
# 0  twdb000 2022-08-14 23:00:00  12.777922  116.048890
# 1  twdb001 2022-08-14 23:00:00  11.791866  120.285871
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_006.csv as 2022 08 14 18 06
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station   Datetime    SPD_mph         DIR
# 0  twdb000 2022-08-15  11.615136  125.798893
# 1  twdb001 2022-08-15  10.570155  128.433613
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_007.csv as 2022 08 14 18 07
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime   SPD_mph         DIR
# 0  twdb000 2022-08-15 01:00:00  6.836157  131.373666
# 1  twdb001 2022-08-15 01:00:00  5.682739  129.034982
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_008.csv as 2022 08 14 18 08
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime   SPD_mph         DIR
# 0  twdb000 2022-08-15 02:00:00  5.518602  103.963441
# 1  twdb001 2022-08-15 02:00:00  5.478432  106.005968
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_009.csv as 2022 08 14 18 09
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime   SPD_mph         DIR
# 0  twdb000 2022-08-15 03:00:00  5.930237   95.852352
# 1  twdb001 2022-08-15 03:00:00  6.039352  101.328009
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_010.csv as 2022 08 14 18 10
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime   SPD_mph        DIR
# 0  twdb000 2022-08-15 04:00:00  5.858402  95.364029
# 1  twdb001 2022-08-15 04:00:00  6.148875  99.947187
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_011.csv as 2022 08 14 18 11
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime   SPD_mph         DIR
# 0  twdb000 2022-08-15 05:00:00  4.407813   98.461646
# 1  twdb001 2022-08-15 05:00:00  4.305888  101.080679
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_012.csv as 2022 08 14 18 12
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime   SPD_mph        DIR
# 0  twdb000 2022-08-15 06:00:00  3.645498  85.592233
# 1  twdb001 2022-08-15 06:00:00  3.478287  90.543594
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_013.csv as 2022 08 14 18 13
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime   SPD_mph        DIR
# 0  twdb000 2022-08-15 07:00:00  4.107174  68.887533
# 1  twdb001 2022-08-15 07:00:00  3.706561  71.660930
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_014.csv as 2022 08 14 18 14
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime   SPD_mph        DIR
# 0  twdb000 2022-08-15 08:00:00  4.350108  55.759025
# 1  twdb001 2022-08-15 08:00:00  4.151909  55.390225
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_015.csv as 2022 08 14 18 15
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime   SPD_mph        DIR
# 0  twdb000 2022-08-15 09:00:00  4.715662  61.426300
# 1  twdb001 2022-08-15 09:00:00  4.542967  59.581105
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_016.csv as 2022 08 14 18 16
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime   SPD_mph        DIR
# 0  twdb000 2022-08-15 10:00:00  4.963013  76.514829
# 1  twdb001 2022-08-15 10:00:00  4.794629  75.756176
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_017.csv as 2022 08 14 18 17
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime   SPD_mph        DIR
# 0  twdb000 2022-08-15 11:00:00  6.314876  84.586309
# 1  twdb001 2022-08-15 11:00:00  6.091942  87.341021
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_018.csv as 2022 08 14 18 18
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime   SPD_mph        DIR
# 0  twdb000 2022-08-15 12:00:00  6.659677  95.787290
# 1  twdb001 2022-08-15 12:00:00  6.377525  99.492869
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_019.csv as 2022 08 14 18 19
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime   SPD_mph         DIR
# 0  twdb000 2022-08-15 13:00:00  6.872280  103.600516
# 1  twdb001 2022-08-15 13:00:00  6.112697  104.461741
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_020.csv as 2022 08 14 18 20
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime   SPD_mph         DIR
# 0  twdb000 2022-08-15 14:00:00  7.475569  114.379884
# 1  twdb001 2022-08-15 14:00:00  6.442682  114.830606
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_021.csv as 2022 08 14 18 21
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime    SPD_mph         DIR
# 0  twdb000 2022-08-15 15:00:00  12.417680  131.710183
# 1  twdb001 2022-08-15 15:00:00  11.911096  133.474141
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_022.csv as 2022 08 14 18 22
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime    SPD_mph         DIR
# 0  twdb000 2022-08-15 16:00:00  13.636134  139.024023
# 1  twdb001 2022-08-15 16:00:00  13.842727  140.606394
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_023.csv as 2022 08 14 18 23
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime    SPD_mph        DIR
# 0  twdb000 2022-08-15 17:00:00  13.564306  136.24082
# 1  twdb001 2022-08-15 17:00:00  13.720802  137.87907
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_024.csv as 2022 08 14 18 24
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime    SPD_mph         DIR
# 0  twdb000 2022-08-15 18:00:00  13.756382  133.989510
# 1  twdb001 2022-08-15 18:00:00  13.723100  134.515426
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_025.csv as 2022 08 14 18 25
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime    SPD_mph         DIR
# 0  twdb000 2022-08-15 19:00:00  14.513651  136.874918
# 1  twdb001 2022-08-15 19:00:00  14.465713  136.818450
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_026.csv as 2022 08 14 18 26
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime    SPD_mph         DIR
# 0  twdb000 2022-08-15 20:00:00  15.479839  141.434620
# 1  twdb001 2022-08-15 20:00:00  15.301649  141.331069
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_027.csv as 2022 08 14 18 27
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime    SPD_mph         DIR
# 0  twdb000 2022-08-15 21:00:00  15.572610  144.886208
# 1  twdb001 2022-08-15 21:00:00  15.295449  145.790166
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_028.csv as 2022 08 14 18 28
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime    SPD_mph         DIR
# 0  twdb000 2022-08-15 22:00:00  15.219427  147.769518
# 1  twdb001 2022-08-15 22:00:00  15.077619  149.128063
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_029.csv as 2022 08 14 18 29
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime    SPD_mph         DIR
# 0  twdb000 2022-08-15 23:00:00  14.457092  146.557588
# 1  twdb001 2022-08-15 23:00:00  14.504861  147.733259
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_030.csv as 2022 08 14 18 30
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station   Datetime    SPD_mph         DIR
# 0  twdb000 2022-08-16  12.781765  143.501406
# 1  twdb001 2022-08-16  12.801084  144.061568
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_031.csv as 2022 08 14 18 31
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime    SPD_mph         DIR
# 0  twdb000 2022-08-16 01:00:00  10.335734  138.974937
# 1  twdb001 2022-08-16 01:00:00  10.087970  139.433069
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_032.csv as 2022 08 14 18 32
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime   SPD_mph         DIR
# 0  twdb000 2022-08-16 02:00:00  8.496488  135.048661
# 1  twdb001 2022-08-16 02:00:00  7.785868  134.005447
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_033.csv as 2022 08 14 18 33
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime   SPD_mph         DIR
# 0  twdb000 2022-08-16 03:00:00  6.417049  131.471023
# 1  twdb001 2022-08-16 03:00:00  5.658501  129.228936
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_034.csv as 2022 08 14 18 34
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime   SPD_mph         DIR
# 0  twdb000 2022-08-16 04:00:00  5.403080  131.583513
# 1  twdb001 2022-08-16 04:00:00  4.873544  130.092785
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_035.csv as 2022 08 14 18 35
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime   SPD_mph         DIR
# 0  twdb000 2022-08-16 05:00:00  4.682541  133.217860
# 1  twdb001 2022-08-16 05:00:00  4.428662  133.525121
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_036.csv as 2022 08 14 18 36
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime   SPD_mph         DIR
# 0  twdb000 2022-08-16 06:00:00  4.031263  127.144953
# 1  twdb001 2022-08-16 06:00:00  3.961066  129.998778
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_039.csv as 2022 08 14 18 39
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime  SPD_mph         DIR
# 0  twdb000 2022-08-16 09:00:00  3.62913  101.636987
# 1  twdb001 2022-08-16 09:00:00  3.56435  110.854564
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_042.csv as 2022 08 14 18 42
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime   SPD_mph         DIR
# 0  twdb000 2022-08-16 12:00:00  3.817537  117.093789
# 1  twdb001 2022-08-16 12:00:00  2.987101  111.862703
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_045.csv as 2022 08 14 18 45
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime   SPD_mph         DIR
# 0  twdb000 2022-08-16 15:00:00  6.883349  134.871454
# 1  twdb001 2022-08-16 15:00:00  7.279864  134.006970
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_048.csv as 2022 08 14 18 48
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime    SPD_mph         DIR
# 0  twdb000 2022-08-16 18:00:00   9.222145  140.484735
# 1  twdb001 2022-08-16 18:00:00  10.209701  138.350761
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_051.csv as 2022 08 14 18 51
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime    SPD_mph         DIR
# 0  twdb000 2022-08-16 21:00:00  13.587601  159.508986
# 1  twdb001 2022-08-16 21:00:00  13.558387  164.827709
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_054.csv as 2022 08 14 18 54
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station   Datetime    SPD_mph         DIR
# 0  twdb000 2022-08-17  13.333832  152.541641
# 1  twdb001 2022-08-17  13.212420  153.791549
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_057.csv as 2022 08 14 18 57
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime   SPD_mph         DIR
# 0  twdb000 2022-08-17 03:00:00  7.162156  151.335169
# 1  twdb001 2022-08-17 03:00:00  6.297689  152.594690
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_060.csv as 2022 08 14 18 60
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime   SPD_mph         DIR
# 0  twdb000 2022-08-17 06:00:00  6.193482  169.353249
# 1  twdb001 2022-08-17 06:00:00  5.989896  170.509092
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_063.csv as 2022 08 14 18 63
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime   SPD_mph         DIR
# 0  twdb000 2022-08-17 09:00:00  4.530639  189.800237
# 1  twdb001 2022-08-17 09:00:00  4.183395  192.499164
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_066.csv as 2022 08 14 18 66
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime   SPD_mph         DIR
# 0  twdb000 2022-08-17 12:00:00  2.970754  188.565781
# 1  twdb001 2022-08-17 12:00:00  2.349906  193.083643
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_069.csv as 2022 08 14 18 69
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime   SPD_mph         DIR
# 0  twdb000 2022-08-17 15:00:00  2.434448  221.336578
# 1  twdb001 2022-08-17 15:00:00  2.365493  238.206480
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_072.csv as 2022 08 14 18 72
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime   SPD_mph         DIR
# 0  twdb000 2022-08-17 18:00:00  4.611444  218.401269
# 1  twdb001 2022-08-17 18:00:00  5.043768  216.796003
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_075.csv as 2022 08 14 18 75
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime   SPD_mph         DIR
# 0  twdb000 2022-08-17 21:00:00  5.752346  178.017527
# 1  twdb001 2022-08-17 21:00:00  6.331455  179.008882
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_078.csv as 2022 08 14 18 78
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station   Datetime    SPD_mph         DIR
# 0  twdb000 2022-08-18  14.843487  166.281238
# 1  twdb001 2022-08-18  15.337349  169.719193
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_081.csv as 2022 08 14 18 81
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime    SPD_mph         DIR
# 0  twdb000 2022-08-18 03:00:00  11.835154  177.416337
# 1  twdb001 2022-08-18 03:00:00  11.555707  179.240243
# DEBUG:root:read_TWDB_NAM_csv() Detected the timestamp from file nam_218_20220814_1800_084.csv as 2022 08 14 18 84
# DEBUG:root:read_TWDB_NAM_csv() Our completed ingested file looks like:
#     station            Datetime   SPD_mph         DIR
# 0  twdb000 2022-08-18 06:00:00  9.625691  195.057257
# 1  twdb001 2022-08-18 06:00:00  9.499627  196.806121
# INFO:root:Loading wind data from disk: COMPLETED - with 53 records
# DEBUG:root:Created one dataframe with record length 18073 from 2022-08-14 18:00:00 to 2022-08-18 06:00:00
# DEBUG:root:Our dataframe looks like:
#       station            Datetime    SPD_mph         DIR
# 0    twdb000 2022-08-14 18:00:00  15.128582  102.088511
# 232  twdb232 2022-08-14 18:00:00  11.008219  174.249245
#       station            Datetime    SPD_mph         DIR
# 115  twdb115 2022-08-18 06:00:00  14.597284  210.968824
# 340  twdb340 2022-08-18 06:00:00  13.413322  232.198061
# DEBUG:root:Entering Print_Winds_TXBLEND_FMT() with bigframe of len 18073, NAMwinds.latlist.csv, twdb-winds-test
# INFO:root:Writing wind data in TXBLEND format: STARTING
# DEBUG:root:Openned twdb_wind_list for reading with 341 entries
# DEBUG:root:Running check on our df columns Index(['station', 'Datetime', 'SPD_mph', 'DIR'], dtype='object') to expected ['station', 'Datetime', 'SPD_mph', 'DIR']
# DEBUG:root:Processing station twdb000
# DEBUG:root:Our sliced df has len 53 and looks like    station            Datetime    SPD_mph         DIR
# 0  twdb000 2022-08-14 18:00:00  15.128582  102.088511
# 0  twdb000 2022-08-14 19:00:00  16.388135  104.790920
# DEBUG:root:Writing file twdb-winds-test\twdb000.wndq COMPLETED
# DEBUG:root:Processing station twdb232
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 232  twdb232 2022-08-14 18:00:00  11.008219  174.249245
# 232  twdb232 2022-08-14 19:00:00  13.715817  162.895411
# DEBUG:root:Writing file twdb-winds-test\twdb232.wndq COMPLETED
# DEBUG:root:Processing station twdb231
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 231  twdb231 2022-08-14 18:00:00  10.627772  173.071735
# 231  twdb231 2022-08-14 19:00:00  13.415170  161.293651
# DEBUG:root:Writing file twdb-winds-test\twdb231.wndq COMPLETED
# DEBUG:root:Processing station twdb230
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 230  twdb230 2022-08-14 18:00:00  10.435667  171.704259
# 230  twdb230 2022-08-14 19:00:00  13.102262  159.894921
# DEBUG:root:Writing file twdb-winds-test\twdb230.wndq COMPLETED
# DEBUG:root:Processing station twdb229
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 229  twdb229 2022-08-14 18:00:00  10.625395  169.898602
# 229  twdb229 2022-08-14 19:00:00  13.005830  158.790988
# DEBUG:root:Writing file twdb-winds-test\twdb229.wndq COMPLETED
# DEBUG:root:Processing station twdb228
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 228  twdb228 2022-08-14 18:00:00  8.311998  187.218457
# 228  twdb228 2022-08-14 19:00:00  7.049335  173.378489
# DEBUG:root:Writing file twdb-winds-test\twdb228.wndq COMPLETED
# DEBUG:root:Processing station twdb227
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 227  twdb227 2022-08-14 18:00:00  8.362245  194.672879
# 227  twdb227 2022-08-14 19:00:00  7.035381  176.839842
# DEBUG:root:Writing file twdb-winds-test\twdb227.wndq COMPLETED
# DEBUG:root:Processing station twdb226
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 226  twdb226 2022-08-14 18:00:00  8.485719  198.551295
# 226  twdb226 2022-08-14 19:00:00  7.189460  177.264638
# DEBUG:root:Writing file twdb-winds-test\twdb226.wndq COMPLETED
# DEBUG:root:Processing station twdb225
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 225  twdb225 2022-08-14 18:00:00  8.594897  196.899175
# 225  twdb225 2022-08-14 19:00:00  7.669503  174.084059
# DEBUG:root:Writing file twdb-winds-test\twdb225.wndq COMPLETED
# DEBUG:root:Processing station twdb224
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 224  twdb224 2022-08-14 18:00:00  9.205601  192.588332
# 224  twdb224 2022-08-14 19:00:00  8.783799  172.193147
# DEBUG:root:Writing file twdb-winds-test\twdb224.wndq COMPLETED
# DEBUG:root:Processing station twdb223
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 223  twdb223 2022-08-14 18:00:00   9.902622  188.664503
# 223  twdb223 2022-08-14 19:00:00  10.071761  171.269972
# DEBUG:root:Writing file twdb-winds-test\twdb223.wndq COMPLETED
# DEBUG:root:Processing station twdb222
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 222  twdb222 2022-08-14 18:00:00   9.818573  184.402062
# 222  twdb222 2022-08-14 19:00:00  10.816123  168.628271
# DEBUG:root:Writing file twdb-winds-test\twdb222.wndq COMPLETED
# DEBUG:root:Processing station twdb221
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 221  twdb221 2022-08-14 18:00:00  10.015648  181.240089
# 221  twdb221 2022-08-14 19:00:00  11.631726  167.184588
# DEBUG:root:Writing file twdb-winds-test\twdb221.wndq COMPLETED
# DEBUG:root:Processing station twdb220
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 220  twdb220 2022-08-14 18:00:00  10.553200  178.626277
# 220  twdb220 2022-08-14 19:00:00  12.556895  166.153850
# DEBUG:root:Writing file twdb-winds-test\twdb220.wndq COMPLETED
# DEBUG:root:Processing station twdb219
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 219  twdb219 2022-08-14 18:00:00  10.756538  175.908382
# 219  twdb219 2022-08-14 19:00:00  13.190931  164.424244
# DEBUG:root:Writing file twdb-winds-test\twdb219.wndq COMPLETED
# DEBUG:root:Processing station twdb218
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 218  twdb218 2022-08-14 18:00:00  10.624308  175.736408
# 218  twdb218 2022-08-14 19:00:00  13.353778  164.419735
# DEBUG:root:Writing file twdb-winds-test\twdb218.wndq COMPLETED
# DEBUG:root:Processing station twdb217
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 217  twdb217 2022-08-14 18:00:00  10.375633  175.881759
# 217  twdb217 2022-08-14 19:00:00  13.296754  164.950943
# DEBUG:root:Writing file twdb-winds-test\twdb217.wndq COMPLETED
# DEBUG:root:Processing station twdb216
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 216  twdb216 2022-08-14 18:00:00  10.001598  175.341855
# 216  twdb216 2022-08-14 19:00:00  12.988652  164.687541
# DEBUG:root:Writing file twdb-winds-test\twdb216.wndq COMPLETED
# DEBUG:root:Processing station twdb233
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 233  twdb233 2022-08-14 18:00:00  11.283383  175.188374
# 233  twdb233 2022-08-14 19:00:00  13.777872  163.654600
# DEBUG:root:Writing file twdb-winds-test\twdb233.wndq COMPLETED
# DEBUG:root:Processing station twdb215
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 215  twdb215 2022-08-14 18:00:00   9.657143  174.375685
# 215  twdb215 2022-08-14 19:00:00  12.530674  163.474285
# DEBUG:root:Writing file twdb-winds-test\twdb215.wndq COMPLETED
# DEBUG:root:Processing station twdb234
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 234  twdb234 2022-08-14 18:00:00  11.348413  175.329335
# 234  twdb234 2022-08-14 19:00:00  13.640483  163.289169
# DEBUG:root:Writing file twdb-winds-test\twdb234.wndq COMPLETED
# DEBUG:root:Processing station twdb236
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 236  twdb236 2022-08-14 18:00:00  11.451492  178.062257
# 236  twdb236 2022-08-14 19:00:00  13.037714  164.644648
# DEBUG:root:Writing file twdb-winds-test\twdb236.wndq COMPLETED
# DEBUG:root:Processing station twdb253
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 253  twdb253 2022-08-14 18:00:00  10.981543  186.631161
# 253  twdb253 2022-08-14 19:00:00  11.279787  167.360514
# DEBUG:root:Writing file twdb-winds-test\twdb253.wndq COMPLETED
# DEBUG:root:Processing station twdb252
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 252  twdb252 2022-08-14 18:00:00  11.780486  179.966267
# 252  twdb252 2022-08-14 19:00:00  12.650631  163.424118
# DEBUG:root:Writing file twdb-winds-test\twdb252.wndq COMPLETED
# DEBUG:root:Processing station twdb251
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 251  twdb251 2022-08-14 18:00:00  11.827781  176.279508
# 251  twdb251 2022-08-14 19:00:00  13.188674  161.473376
# DEBUG:root:Writing file twdb-winds-test\twdb251.wndq COMPLETED
# DEBUG:root:Processing station twdb250
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 250  twdb250 2022-08-14 18:00:00  11.835565  175.739191
# 250  twdb250 2022-08-14 19:00:00  13.493434  162.106229
# DEBUG:root:Writing file twdb-winds-test\twdb250.wndq COMPLETED
# DEBUG:root:Processing station twdb249
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 249  twdb249 2022-08-14 18:00:00  12.000444  175.262197
# 249  twdb249 2022-08-14 19:00:00  13.919858  162.672045
# DEBUG:root:Writing file twdb-winds-test\twdb249.wndq COMPLETED
# DEBUG:root:Processing station twdb248
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 248  twdb248 2022-08-14 18:00:00  11.862656  173.252271
# 248  twdb248 2022-08-14 19:00:00  14.129729  161.221322
# DEBUG:root:Writing file twdb-winds-test\twdb248.wndq COMPLETED
# DEBUG:root:Processing station twdb247
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 247  twdb247 2022-08-14 18:00:00  11.540885  171.044755
# 247  twdb247 2022-08-14 19:00:00  14.117697  159.469336
# DEBUG:root:Writing file twdb-winds-test\twdb247.wndq COMPLETED
# DEBUG:root:Processing station twdb246
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 246  twdb246 2022-08-14 18:00:00  11.356074  169.178875
# 246  twdb246 2022-08-14 19:00:00  14.022971  157.950317
# DEBUG:root:Writing file twdb-winds-test\twdb246.wndq COMPLETED
# DEBUG:root:Processing station twdb245
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 245  twdb245 2022-08-14 18:00:00  8.671220  180.249787
# 245  twdb245 2022-08-14 19:00:00  7.383145  167.339760
# DEBUG:root:Writing file twdb-winds-test\twdb245.wndq COMPLETED
# DEBUG:root:Processing station twdb244
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 244  twdb244 2022-08-14 18:00:00  8.403584  187.293108
# 244  twdb244 2022-08-14 19:00:00  6.996855  169.995696
# DEBUG:root:Writing file twdb-winds-test\twdb244.wndq COMPLETED
# DEBUG:root:Processing station twdb243
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 243  twdb243 2022-08-14 18:00:00  8.432698  193.451071
# 243  twdb243 2022-08-14 19:00:00  6.863565  172.257174
# DEBUG:root:Writing file twdb-winds-test\twdb243.wndq COMPLETED
# DEBUG:root:Processing station twdb242
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 242  twdb242 2022-08-14 18:00:00  8.698200  196.078206
# 242  twdb242 2022-08-14 19:00:00  7.202074  172.264139
# DEBUG:root:Writing file twdb-winds-test\twdb242.wndq COMPLETED
# DEBUG:root:Processing station twdb241
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 241  twdb241 2022-08-14 18:00:00  8.766047  195.494758
# 241  twdb241 2022-08-14 19:00:00  7.699200  170.072508
# DEBUG:root:Writing file twdb-winds-test\twdb241.wndq COMPLETED
# DEBUG:root:Processing station twdb240
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 240  twdb240 2022-08-14 18:00:00  9.278891  194.475976
# 240  twdb240 2022-08-14 19:00:00  8.588998  170.807600
# DEBUG:root:Writing file twdb-winds-test\twdb240.wndq COMPLETED
# DEBUG:root:Processing station twdb239
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 239  twdb239 2022-08-14 18:00:00  9.772616  193.594924
# 239  twdb239 2022-08-14 19:00:00  9.446302  172.880483
# DEBUG:root:Writing file twdb-winds-test\twdb239.wndq COMPLETED
# DEBUG:root:Processing station twdb238
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 238  twdb238 2022-08-14 18:00:00   9.924586  190.216155
# 238  twdb238 2022-08-14 19:00:00  10.274152  171.317076
# DEBUG:root:Writing file twdb-winds-test\twdb238.wndq COMPLETED
# DEBUG:root:Processing station twdb237
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 237  twdb237 2022-08-14 18:00:00  10.685554  183.803824
# 237  twdb237 2022-08-14 19:00:00  11.694876  167.816150
# DEBUG:root:Writing file twdb-winds-test\twdb237.wndq COMPLETED
# DEBUG:root:Processing station twdb235
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 235  twdb235 2022-08-14 18:00:00  11.478675  175.606460
# 235  twdb235 2022-08-14 19:00:00  13.497105  163.007086
# DEBUG:root:Writing file twdb-winds-test\twdb235.wndq COMPLETED
# DEBUG:root:Processing station twdb214
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 214  twdb214 2022-08-14 18:00:00   9.573369  172.844321
# 214  twdb214 2022-08-14 19:00:00  12.170770  162.198347
# DEBUG:root:Writing file twdb-winds-test\twdb214.wndq COMPLETED
# DEBUG:root:Processing station twdb213
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 213  twdb213 2022-08-14 18:00:00   9.845331  170.147600
# 213  twdb213 2022-08-14 19:00:00  12.114031  160.996837
# DEBUG:root:Writing file twdb-winds-test\twdb213.wndq COMPLETED
# DEBUG:root:Processing station twdb212
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 212  twdb212 2022-08-14 18:00:00  10.286185  167.910124
# 212  twdb212 2022-08-14 19:00:00  12.196374  159.903818
# DEBUG:root:Writing file twdb-winds-test\twdb212.wndq COMPLETED
# DEBUG:root:Processing station twdb189
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 189  twdb189 2022-08-14 18:00:00   8.777984  172.044660
# 189  twdb189 2022-08-14 19:00:00  10.953385  161.380664
# DEBUG:root:Writing file twdb-winds-test\twdb189.wndq COMPLETED
# DEBUG:root:Processing station twdb188
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 188  twdb188 2022-08-14 18:00:00   9.025088  174.551297
# 188  twdb188 2022-08-14 19:00:00  11.264306  164.409321
# DEBUG:root:Writing file twdb-winds-test\twdb188.wndq COMPLETED
# DEBUG:root:Processing station twdb187
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 187  twdb187 2022-08-14 18:00:00   9.250567  176.213418
# 187  twdb187 2022-08-14 19:00:00  11.494362  166.685272
# DEBUG:root:Writing file twdb-winds-test\twdb187.wndq COMPLETED
# DEBUG:root:Processing station twdb186
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 186  twdb186 2022-08-14 18:00:00   9.234602  175.650294
# 186  twdb186 2022-08-14 19:00:00  11.583146  167.243397
# DEBUG:root:Writing file twdb-winds-test\twdb186.wndq COMPLETED
# DEBUG:root:Processing station twdb185
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 185  twdb185 2022-08-14 18:00:00   9.121391  175.737117
# 185  twdb185 2022-08-14 19:00:00  11.461083  168.478227
# DEBUG:root:Writing file twdb-winds-test\twdb185.wndq COMPLETED
# DEBUG:root:Processing station twdb184
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 184  twdb184 2022-08-14 18:00:00   9.011568  175.542425
# 184  twdb184 2022-08-14 19:00:00  11.120371  169.647153
# DEBUG:root:Writing file twdb-winds-test\twdb184.wndq COMPLETED
# DEBUG:root:Processing station twdb183
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 183  twdb183 2022-08-14 18:00:00   9.147605  173.920420
# 183  twdb183 2022-08-14 19:00:00  10.895195  168.951706
# DEBUG:root:Writing file twdb-winds-test\twdb183.wndq COMPLETED
# DEBUG:root:Processing station twdb182
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 182  twdb182 2022-08-14 18:00:00   9.492068  170.599245
# 182  twdb182 2022-08-14 19:00:00  11.039819  167.081076
# DEBUG:root:Writing file twdb-winds-test\twdb182.wndq COMPLETED
# DEBUG:root:Processing station twdb181
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 181  twdb181 2022-08-14 18:00:00   9.782012  166.738959
# 181  twdb181 2022-08-14 19:00:00  11.271242  165.596367
# DEBUG:root:Writing file twdb-winds-test\twdb181.wndq COMPLETED
# DEBUG:root:Processing station twdb180
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 180  twdb180 2022-08-14 18:00:00  10.156520  163.189569
# 180  twdb180 2022-08-14 19:00:00  11.356503  164.421943
# DEBUG:root:Writing file twdb-winds-test\twdb180.wndq COMPLETED
# DEBUG:root:Processing station twdb179
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 179  twdb179 2022-08-14 18:00:00   9.655675  179.560626
# 179  twdb179 2022-08-14 19:00:00  10.508996  172.743782
# DEBUG:root:Writing file twdb-winds-test\twdb179.wndq COMPLETED
# DEBUG:root:Processing station twdb178
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 178  twdb178 2022-08-14 18:00:00   9.548951  185.874405
# 178  twdb178 2022-08-14 19:00:00  10.347426  177.232051
# DEBUG:root:Writing file twdb-winds-test\twdb178.wndq COMPLETED
# DEBUG:root:Processing station twdb177
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 177  twdb177 2022-08-14 18:00:00   9.450061  187.711883
# 177  twdb177 2022-08-14 19:00:00  10.204870  178.450229
# DEBUG:root:Writing file twdb-winds-test\twdb177.wndq COMPLETED
# DEBUG:root:Processing station twdb176
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 176  twdb176 2022-08-14 18:00:00   9.325642  182.019334
# 176  twdb176 2022-08-14 19:00:00  10.373030  172.772714
# DEBUG:root:Writing file twdb-winds-test\twdb176.wndq COMPLETED
# DEBUG:root:Processing station twdb175
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 175  twdb175 2022-08-14 18:00:00   9.201954  173.395918
# 175  twdb175 2022-08-14 19:00:00  10.801110  164.832039
# DEBUG:root:Writing file twdb-winds-test\twdb175.wndq COMPLETED
# DEBUG:root:Processing station twdb174
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 174  twdb174 2022-08-14 18:00:00   8.938902  169.282936
# 174  twdb174 2022-08-14 19:00:00  10.910906  161.677114
# DEBUG:root:Writing file twdb-winds-test\twdb174.wndq COMPLETED
# DEBUG:root:Processing station twdb173
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 173  twdb173 2022-08-14 18:00:00   8.651480  171.628197
# 173  twdb173 2022-08-14 19:00:00  10.637276  163.966815
# DEBUG:root:Writing file twdb-winds-test\twdb173.wndq COMPLETED
# DEBUG:root:Processing station twdb190
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 190  twdb190 2022-08-14 18:00:00   8.996680  174.963224
# 190  twdb190 2022-08-14 19:00:00  10.705241  163.572679
# DEBUG:root:Writing file twdb-winds-test\twdb190.wndq COMPLETED
# DEBUG:root:Processing station twdb191
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 191  twdb191 2022-08-14 18:00:00   9.303286  182.024189
# 191  twdb191 2022-08-14 19:00:00  10.343076  170.496992
# DEBUG:root:Writing file twdb-winds-test\twdb191.wndq COMPLETED
# DEBUG:root:Processing station twdb192
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 192  twdb192 2022-08-14 18:00:00  9.361401  187.785372
# 192  twdb192 2022-08-14 19:00:00  9.930588  176.340121
# DEBUG:root:Writing file twdb-winds-test\twdb192.wndq COMPLETED
# DEBUG:root:Processing station twdb193
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 193  twdb193 2022-08-14 18:00:00  9.368698  189.023885
# 193  twdb193 2022-08-14 19:00:00  9.785685  177.466394
# DEBUG:root:Writing file twdb-winds-test\twdb193.wndq COMPLETED
# DEBUG:root:Processing station twdb211
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 211  twdb211 2022-08-14 18:00:00  8.259097  183.212412
# 211  twdb211 2022-08-14 19:00:00  7.506872  172.924257
# DEBUG:root:Writing file twdb-winds-test\twdb211.wndq COMPLETED
# DEBUG:root:Processing station twdb210
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 210  twdb210 2022-08-14 18:00:00  8.438233  189.874480
# 210  twdb210 2022-08-14 19:00:00  7.823585  176.338059
# DEBUG:root:Writing file twdb-winds-test\twdb210.wndq COMPLETED
# DEBUG:root:Processing station twdb209
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 209  twdb209 2022-08-14 18:00:00  8.833868  193.723973
# 209  twdb209 2022-08-14 19:00:00  8.603791  176.819729
# DEBUG:root:Writing file twdb-winds-test\twdb209.wndq COMPLETED
# DEBUG:root:Processing station twdb208
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 208  twdb208 2022-08-14 18:00:00  9.166362  189.083169
# 208  twdb208 2022-08-14 19:00:00  9.366413  173.508527
# DEBUG:root:Writing file twdb-winds-test\twdb208.wndq COMPLETED
# DEBUG:root:Processing station twdb207
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 207  twdb207 2022-08-14 18:00:00   9.559512  183.312098
# 207  twdb207 2022-08-14 19:00:00  10.364567  169.134865
# DEBUG:root:Writing file twdb-winds-test\twdb207.wndq COMPLETED
# DEBUG:root:Processing station twdb206
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 206  twdb206 2022-08-14 18:00:00   9.278561  178.437518
# 206  twdb206 2022-08-14 19:00:00  10.844297  164.893887
# DEBUG:root:Writing file twdb-winds-test\twdb206.wndq COMPLETED
# DEBUG:root:Processing station twdb205
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 205  twdb205 2022-08-14 18:00:00   9.106407  177.281205
# 205  twdb205 2022-08-14 19:00:00  11.178146  164.286056
# DEBUG:root:Writing file twdb-winds-test\twdb205.wndq COMPLETED
# DEBUG:root:Processing station twdb204
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 204  twdb204 2022-08-14 18:00:00   9.683819  177.973262
# 204  twdb204 2022-08-14 19:00:00  11.960073  166.111352
# DEBUG:root:Writing file twdb-winds-test\twdb204.wndq COMPLETED
# DEBUG:root:Processing station twdb254
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 254  twdb254 2022-08-14 18:00:00  9.923953  192.191791
# 254  twdb254 2022-08-14 19:00:00  9.858037  170.024755
# DEBUG:root:Writing file twdb-winds-test\twdb254.wndq COMPLETED
# DEBUG:root:Processing station twdb203
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 203  twdb203 2022-08-14 18:00:00   9.96778  176.228546
# 203  twdb203 2022-08-14 19:00:00  12.49746  165.557796
# DEBUG:root:Writing file twdb-winds-test\twdb203.wndq COMPLETED
# DEBUG:root:Processing station twdb201
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 201  twdb201 2022-08-14 18:00:00   9.561674  176.471099
# 201  twdb201 2022-08-14 19:00:00  12.428124  166.856190
# DEBUG:root:Writing file twdb-winds-test\twdb201.wndq COMPLETED
# DEBUG:root:Processing station twdb200
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 200  twdb200 2022-08-14 18:00:00   9.228247  176.204245
# 200  twdb200 2022-08-14 19:00:00  12.005566  167.042979
# DEBUG:root:Writing file twdb-winds-test\twdb200.wndq COMPLETED
# DEBUG:root:Processing station twdb199
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 199  twdb199 2022-08-14 18:00:00   9.069626  174.578134
# 199  twdb199 2022-08-14 19:00:00  11.596537  166.008758
# DEBUG:root:Writing file twdb-winds-test\twdb199.wndq COMPLETED
# DEBUG:root:Processing station twdb198
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 198  twdb198 2022-08-14 18:00:00   9.167059  171.819745
# 198  twdb198 2022-08-14 19:00:00  11.421160  164.512352
# DEBUG:root:Writing file twdb-winds-test\twdb198.wndq COMPLETED
# DEBUG:root:Processing station twdb197
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 197  twdb197 2022-08-14 18:00:00   9.464912  168.506391
# 197  twdb197 2022-08-14 19:00:00  11.482917  163.436663
# DEBUG:root:Writing file twdb-winds-test\twdb197.wndq COMPLETED
# DEBUG:root:Processing station twdb196
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 196  twdb196 2022-08-14 18:00:00   9.873485  165.661316
# 196  twdb196 2022-08-14 19:00:00  11.484738  162.271471
# DEBUG:root:Writing file twdb-winds-test\twdb196.wndq COMPLETED
# DEBUG:root:Processing station twdb195
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 195  twdb195 2022-08-14 18:00:00  9.163278  180.096502
# 195  twdb195 2022-08-14 19:00:00  9.337320  171.688682
# DEBUG:root:Writing file twdb-winds-test\twdb195.wndq COMPLETED
# DEBUG:root:Processing station twdb194
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 194  twdb194 2022-08-14 18:00:00  9.364192  185.578019
# 194  twdb194 2022-08-14 19:00:00  9.722583  175.071871
# DEBUG:root:Writing file twdb-winds-test\twdb194.wndq COMPLETED
# DEBUG:root:Processing station twdb202
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 202  twdb202 2022-08-14 18:00:00   9.790743  176.029037
# 202  twdb202 2022-08-14 19:00:00  12.556926  165.733008
# DEBUG:root:Writing file twdb-winds-test\twdb202.wndq COMPLETED
# DEBUG:root:Processing station twdb256
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 256  twdb256 2022-08-14 18:00:00  8.861732  193.233840
# 256  twdb256 2022-08-14 19:00:00  8.438947  168.015142
# DEBUG:root:Writing file twdb-winds-test\twdb256.wndq COMPLETED
# DEBUG:root:Processing station twdb257
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 257  twdb257 2022-08-14 18:00:00  8.579983  193.062552
# 257  twdb257 2022-08-14 19:00:00  7.805537  167.026287
# DEBUG:root:Writing file twdb-winds-test\twdb257.wndq COMPLETED
# DEBUG:root:Processing station twdb258
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 258  twdb258 2022-08-14 18:00:00  8.606845  193.173955
# 258  twdb258 2022-08-14 19:00:00  7.307920  167.566680
# DEBUG:root:Writing file twdb-winds-test\twdb258.wndq COMPLETED
# DEBUG:root:Processing station twdb318
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 318  twdb318 2022-08-14 18:00:00  11.812306  169.159994
# 318  twdb318 2022-08-14 19:00:00  11.013921  150.381521
# DEBUG:root:Writing file twdb-winds-test\twdb318.wndq COMPLETED
# DEBUG:root:Processing station twdb317
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 317  twdb317 2022-08-14 18:00:00  12.255092  168.917397
# 317  twdb317 2022-08-14 19:00:00  11.687088  151.244842
# DEBUG:root:Writing file twdb-winds-test\twdb317.wndq COMPLETED
# DEBUG:root:Processing station twdb316
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 316  twdb316 2022-08-14 18:00:00  12.760176  166.484936
# 316  twdb316 2022-08-14 19:00:00  12.474545  151.704965
# DEBUG:root:Writing file twdb-winds-test\twdb316.wndq COMPLETED
# DEBUG:root:Processing station twdb315
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 315  twdb315 2022-08-14 18:00:00  13.327549  163.289713
# 315  twdb315 2022-08-14 19:00:00  13.323193  152.030372
# ...
# 328  twdb328 2022-08-14 19:00:00  9.571764  171.352257
# DEBUG:root:Writing file twdb-winds-test\twdb328.wndq COMPLETED
# DEBUG:root:Processing station twdb327
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 327  twdb327 2022-08-14 18:00:00  9.452371  164.726938
# 327  twdb327 2022-08-14 19:00:00  9.948111  169.330362
# DEBUG:root:Writing file twdb-winds-test\twdb327.wndq COMPLETED
# DEBUG:root:Processing station twdb326
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 326  twdb326 2022-08-14 18:00:00   9.569693  166.301376
# 326  twdb326 2022-08-14 19:00:00  10.324891  168.966158
# DEBUG:root:Writing file twdb-winds-test\twdb326.wndq COMPLETED
# DEBUG:root:Processing station twdb325
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 325  twdb325 2022-08-14 18:00:00  8.844730  167.242931
# 325  twdb325 2022-08-14 19:00:00  8.459449  175.550593
# DEBUG:root:Writing file twdb-winds-test\twdb325.wndq COMPLETED
# DEBUG:root:Processing station twdb324
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 324  twdb324 2022-08-14 18:00:00  8.750927  166.652677
# 324  twdb324 2022-08-14 19:00:00  8.704544  174.049871
# DEBUG:root:Writing file twdb-winds-test\twdb324.wndq COMPLETED
# DEBUG:root:Processing station twdb323
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 323  twdb323 2022-08-14 18:00:00  8.864247  166.082766
# 323  twdb323 2022-08-14 19:00:00  9.185812  172.396058
# DEBUG:root:Writing file twdb-winds-test\twdb323.wndq COMPLETED
# DEBUG:root:Processing station twdb331
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 331  twdb331 2022-08-14 18:00:00   9.718244  167.191924
# 331  twdb331 2022-08-14 19:00:00  10.346880  168.358243
# DEBUG:root:Writing file twdb-winds-test\twdb331.wndq COMPLETED
# DEBUG:root:Processing station twdb172
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 172  twdb172 2022-08-14 18:00:00   8.735644  174.370188
# 172  twdb172 2022-08-14 19:00:00  10.615681  166.803569
# DEBUG:root:Writing file twdb-winds-test\twdb172.wndq COMPLETED
# DEBUG:root:Processing station twdb300
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 300  twdb300 2022-08-14 18:00:00  9.057076  177.974553
# 300  twdb300 2022-08-14 19:00:00  8.877572  156.170634
# DEBUG:root:Writing file twdb-winds-test\twdb300.wndq COMPLETED
# DEBUG:root:Processing station twdb298
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 298  twdb298 2022-08-14 18:00:00  10.015027  178.936460
# 298  twdb298 2022-08-14 19:00:00   9.761326  156.451878
# DEBUG:root:Writing file twdb-winds-test\twdb298.wndq COMPLETED
# DEBUG:root:Processing station twdb275
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 275  twdb275 2022-08-14 18:00:00  8.514538  187.197564
# 275  twdb275 2022-08-14 19:00:00  7.448373  163.361945
# DEBUG:root:Writing file twdb-winds-test\twdb275.wndq COMPLETED
# DEBUG:root:Processing station twdb274
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 274  twdb274 2022-08-14 18:00:00  8.504649  188.880234
# 274  twdb274 2022-08-14 19:00:00  7.635273  163.955356
# DEBUG:root:Writing file twdb-winds-test\twdb274.wndq COMPLETED
# DEBUG:root:Processing station twdb273
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 273  twdb273 2022-08-14 18:00:00  8.467507  189.226066
# 273  twdb273 2022-08-14 19:00:00  8.074655  164.026166
# DEBUG:root:Writing file twdb-winds-test\twdb273.wndq COMPLETED
# DEBUG:root:Processing station twdb272
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 272  twdb272 2022-08-14 18:00:00  8.702811  189.571412
# 272  twdb272 2022-08-14 19:00:00  8.637188  164.476445
# DEBUG:root:Writing file twdb-winds-test\twdb272.wndq COMPLETED
# DEBUG:root:Processing station twdb271
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 271  twdb271 2022-08-14 18:00:00  9.244311  190.271632
# 271  twdb271 2022-08-14 19:00:00  9.210237  165.176628
# DEBUG:root:Writing file twdb-winds-test\twdb271.wndq COMPLETED
# DEBUG:root:Processing station twdb270
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 270  twdb270 2022-08-14 18:00:00  10.218716  190.173834
# 270  twdb270 2022-08-14 19:00:00   9.920108  165.859686
# DEBUG:root:Writing file twdb-winds-test\twdb270.wndq COMPLETED
# DEBUG:root:Processing station twdb269
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 269  twdb269 2022-08-14 18:00:00  11.379553  188.101363
# 269  twdb269 2022-08-14 19:00:00  10.902325  165.583936
# DEBUG:root:Writing file twdb-winds-test\twdb269.wndq COMPLETED
# DEBUG:root:Processing station twdb268
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 268  twdb268 2022-08-14 18:00:00  11.875986  183.962786
# 268  twdb268 2022-08-14 19:00:00  11.722857  163.329161
# DEBUG:root:Writing file twdb-winds-test\twdb268.wndq COMPLETED
# DEBUG:root:Processing station twdb267
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 267  twdb267 2022-08-14 18:00:00  11.848721  179.209248
# 267  twdb267 2022-08-14 19:00:00  12.340868  160.810213
# DEBUG:root:Writing file twdb-winds-test\twdb267.wndq COMPLETED
# DEBUG:root:Processing station twdb266
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 266  twdb266 2022-08-14 18:00:00  12.157316  176.802935
# 266  twdb266 2022-08-14 19:00:00  13.090465  160.915368
# DEBUG:root:Writing file twdb-winds-test\twdb266.wndq COMPLETED
# DEBUG:root:Processing station twdb265
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 265  twdb265 2022-08-14 18:00:00  12.455764  174.919442
# 265  twdb265 2022-08-14 19:00:00  13.769365  161.006275
# DEBUG:root:Writing file twdb-winds-test\twdb265.wndq COMPLETED
# DEBUG:root:Processing station twdb264
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 264  twdb264 2022-08-14 18:00:00  12.216680  171.861938
# 264  twdb264 2022-08-14 19:00:00  14.078651  159.117788
# DEBUG:root:Writing file twdb-winds-test\twdb264.wndq COMPLETED
# DEBUG:root:Processing station twdb263
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 263  twdb263 2022-08-14 18:00:00  12.005018  168.901195
# 263  twdb263 2022-08-14 19:00:00  14.306251  157.539316
# DEBUG:root:Writing file twdb-winds-test\twdb263.wndq COMPLETED
# DEBUG:root:Processing station twdb262
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 262  twdb262 2022-08-14 18:00:00  12.038924  166.645271
# 262  twdb262 2022-08-14 19:00:00  14.546699  156.208213
# DEBUG:root:Writing file twdb-winds-test\twdb262.wndq COMPLETED
# DEBUG:root:Processing station twdb261
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 261  twdb261 2022-08-14 18:00:00  8.782998  180.100681
# 261  twdb261 2022-08-14 19:00:00  7.512909  164.750485
# DEBUG:root:Writing file twdb-winds-test\twdb261.wndq COMPLETED
# DEBUG:root:Processing station twdb260
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 260  twdb260 2022-08-14 18:00:00  8.493972  185.999853
# 260  twdb260 2022-08-14 19:00:00  7.212857  166.122303
# DEBUG:root:Writing file twdb-winds-test\twdb260.wndq COMPLETED
# DEBUG:root:Processing station twdb259
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 259  twdb259 2022-08-14 18:00:00  8.431200  191.274628
# 259  twdb259 2022-08-14 19:00:00  7.014331  167.412125
# DEBUG:root:Writing file twdb-winds-test\twdb259.wndq COMPLETED
# DEBUG:root:Processing station twdb276
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 276  twdb276 2022-08-14 18:00:00  8.663649  183.358600
# 276  twdb276 2022-08-14 19:00:00  7.566569  162.744459
# DEBUG:root:Writing file twdb-winds-test\twdb276.wndq COMPLETED
# DEBUG:root:Processing station twdb277
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 277  twdb277 2022-08-14 18:00:00  8.941066  178.952069
# 277  twdb277 2022-08-14 19:00:00  7.727693  161.723278
# DEBUG:root:Writing file twdb-winds-test\twdb277.wndq COMPLETED
# DEBUG:root:Processing station twdb278
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 278  twdb278 2022-08-14 18:00:00  9.096221  174.310904
# 278  twdb278 2022-08-14 19:00:00  7.800737  160.162956
# DEBUG:root:Writing file twdb-winds-test\twdb278.wndq COMPLETED
# DEBUG:root:Processing station twdb279
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 279  twdb279 2022-08-14 18:00:00  12.141157  165.999439
# 279  twdb279 2022-08-14 19:00:00  14.279170  155.537001
# DEBUG:root:Writing file twdb-winds-test\twdb279.wndq COMPLETED
# DEBUG:root:Processing station twdb297
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 297  twdb297 2022-08-14 18:00:00  10.819349  180.674052
# 297  twdb297 2022-08-14 19:00:00  10.128419  157.079336
# DEBUG:root:Writing file twdb-winds-test\twdb297.wndq COMPLETED
# DEBUG:root:Processing station twdb296
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 296  twdb296 2022-08-14 18:00:00  11.726390  182.699563
# 296  twdb296 2022-08-14 19:00:00  10.600224  158.543725
# DEBUG:root:Writing file twdb-winds-test\twdb296.wndq COMPLETED
# DEBUG:root:Processing station twdb295
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 295  twdb295 2022-08-14 18:00:00  12.176529  182.915835
# 295  twdb295 2022-08-14 19:00:00  10.996887  159.353769
# DEBUG:root:Writing file twdb-winds-test\twdb295.wndq COMPLETED
# DEBUG:root:Processing station twdb294
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 294  twdb294 2022-08-14 18:00:00  12.429418  179.658678
# 294  twdb294 2022-08-14 19:00:00  11.734196  158.490087
# DEBUG:root:Writing file twdb-winds-test\twdb294.wndq COMPLETED
# DEBUG:root:Processing station twdb293
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 293  twdb293 2022-08-14 18:00:00  12.669354  175.512868
# 293  twdb293 2022-08-14 19:00:00  12.499445  157.444011
# DEBUG:root:Writing file twdb-winds-test\twdb293.wndq COMPLETED
# DEBUG:root:Processing station twdb292
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 292  twdb292 2022-08-14 18:00:00  12.426794  170.330369
# 292  twdb292 2022-08-14 19:00:00  13.005647  155.257836
# DEBUG:root:Writing file twdb-winds-test\twdb292.wndq COMPLETED
# DEBUG:root:Processing station twdb291
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 291  twdb291 2022-08-14 18:00:00  12.267821  164.960130
# 291  twdb291 2022-08-14 19:00:00  13.749406  153.282993
# DEBUG:root:Writing file twdb-winds-test\twdb291.wndq COMPLETED
# DEBUG:root:Processing station twdb290
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 290  twdb290 2022-08-14 18:00:00  8.685980  183.349955
# 290  twdb290 2022-08-14 19:00:00  8.104661  160.265567
# DEBUG:root:Writing file twdb-winds-test\twdb290.wndq COMPLETED
# DEBUG:root:Processing station twdb299
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 299  twdb299 2022-08-14 18:00:00  9.392415  178.046897
# 299  twdb299 2022-08-14 19:00:00  9.327259  156.038647
# DEBUG:root:Writing file twdb-winds-test\twdb299.wndq COMPLETED
# DEBUG:root:Processing station twdb289
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph        DIR
# 289  twdb289 2022-08-14 18:00:00  8.690160  183.79166
# 289  twdb289 2022-08-14 19:00:00  8.486872  160.22856
# DEBUG:root:Writing file twdb-winds-test\twdb289.wndq COMPLETED
# DEBUG:root:Processing station twdb287
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 287  twdb287 2022-08-14 18:00:00  9.621463  184.759719
# 287  twdb287 2022-08-14 19:00:00  9.519116  160.458684
# DEBUG:root:Writing file twdb-winds-test\twdb287.wndq COMPLETED
# DEBUG:root:Processing station twdb286
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 286  twdb286 2022-08-14 18:00:00  10.586314  186.027010
# 286  twdb286 2022-08-14 19:00:00  10.069347  161.163217
# DEBUG:root:Writing file twdb-winds-test\twdb286.wndq COMPLETED
# DEBUG:root:Processing station twdb285
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 285  twdb285 2022-08-14 18:00:00  11.661100  186.796271
# 285  twdb285 2022-08-14 19:00:00  10.650509  162.479041
# DEBUG:root:Writing file twdb-winds-test\twdb285.wndq COMPLETED
# DEBUG:root:Processing station twdb284
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 284  twdb284 2022-08-14 18:00:00  12.155376  185.776329
# 284  twdb284 2022-08-14 19:00:00  11.138886  162.548135
# DEBUG:root:Writing file twdb-winds-test\twdb284.wndq COMPLETED
# DEBUG:root:Processing station twdb283
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 283  twdb283 2022-08-14 18:00:00  12.232287  181.539365
# 283  twdb283 2022-08-14 19:00:00  11.839456  160.538584
# DEBUG:root:Writing file twdb-winds-test\twdb283.wndq COMPLETED
# DEBUG:root:Processing station twdb282
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 282  twdb282 2022-08-14 18:00:00  12.577191  177.317907
# 282  twdb282 2022-08-14 19:00:00  12.792964  159.600947
# DEBUG:root:Writing file twdb-winds-test\twdb282.wndq COMPLETED
# DEBUG:root:Processing station twdb281
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 281  twdb281 2022-08-14 18:00:00  12.578837  173.433006
# 281  twdb281 2022-08-14 19:00:00  13.428889  158.364687
# DEBUG:root:Writing file twdb-winds-test\twdb281.wndq COMPLETED
# DEBUG:root:Processing station twdb280
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 280  twdb280 2022-08-14 18:00:00  12.172266  169.270003
# 280  twdb280 2022-08-14 19:00:00  13.797332  156.358963
# DEBUG:root:Writing file twdb-winds-test\twdb280.wndq COMPLETED
# DEBUG:root:Processing station twdb288
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime   SPD_mph         DIR
# 288  twdb288 2022-08-14 18:00:00  9.007202  184.085873
# 288  twdb288 2022-08-14 19:00:00  9.002976  160.350219
# DEBUG:root:Writing file twdb-winds-test\twdb288.wndq COMPLETED
# DEBUG:root:Processing station twdb171
# DEBUG:root:Our sliced df has len 53 and looks like      station            Datetime    SPD_mph         DIR
# 171  twdb171 2022-08-14 18:00:00   8.873657  174.167725
# 171  twdb171 2022-08-14 19:00:00  10.724675  168.041799
